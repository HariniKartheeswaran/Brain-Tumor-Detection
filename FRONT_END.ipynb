# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Brain
# Out:
# /content/drive/MyDrive/Brain

# %%
import tensorflow as tf

# Load your pre-trained model
model = tf.keras.models.load_model('history.h5')

# %%
# !pip install streamlit
# !pip install pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 66.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok
# !ngrok authtoken 2h2qYaAVVXsIV42LfJbxXrhqG6Q_2TxtF3WvxyYskh9qpvijd
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install --upgrade pyngrok
# !pip install --upgrade streamlit

# %%
# !ngrok authtoken 2h2qYaAVVXsIV42LfJbxXrhqG6Q_2TxtF3WvxyYskh9qpvijd
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# %%writefile app.py
import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np

# Load the model
model = tf.keras.models.load_model('history.h5')

st.write("""
# Brain Tumor Detection
Upload an MRI image to detect if there is a brain tumor.
""")

# File uploader allows user to upload an image
file = st.file_uploader("Please upload an MRI image", type=["jpg", "png", "jpeg"])

def import_and_predict(image_data, model):
    size = (224, 224)  # Match the input shape of your model
    image = ImageOps.fit(image_data, size, Image.ANTIALIAS)
    img = np.asarray(image)
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=-1)  # Add channel dimension if missing
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    prediction = model.predict(img)
    return prediction

if file is None:
    st.text("Please upload an image file")
else:
    image = Image.open(file).convert('RGB')  # Ensure image is in RGB format
    st.image(image, use_column_width=True)
    predictions = import_and_predict(image, model)
    class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']
    string = "The given MRI is identified as -  " + class_names[np.argmax(predictions)]
    st.success(string)
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok
import time

# Start Ngrok tunnel
public_url = ngrok.connect(8501)
print(f"Public URL: {public_url}")

# Run the Streamlit app
time.sleep(2)  # Give Ngrok time to set up the tunnel
# !streamlit run app.py &

# Keep the connection alive
ngrok_process = ngrok.get_ngrok_process()
try:
    ngrok_process.proc.wait()
except KeyboardInterrupt:
    print("Shutting down server.")
    ngrok.kill()
# Out:
# Public URL: NgrokTunnel: "https://cb07-34-73-232-200.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.73.232.200:8501
#
# 2024-06-21 04:42:55.776652: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-21 04:42:55.776745: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-21 04:42:55.780280: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
